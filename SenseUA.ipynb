# %% [markdown]
# <a href="https://colab.research.google.com/github/roshanedachali/SenseUA/blob/main/SenseUA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing all necessary dictionaries
from google.colab import files
uploaded = files.upload()
import pandas as pd
import io
from sklearn.model_selection import train_test_split
from sklearn.metrics  import f1_score,accuracy_score
from sklearn.tree import DecisionTreeClassifier
import itertools
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from random import randrange


#Cleaning up CSV file and making it a usable dataframe (df)
df = pd.read_csv(io.BytesIO(uploaded['Field Cleaning Master CSV.csv']))
df.head()
df = df.assign(ColumnR = df.R1.astype(str) + ', ' + df.R2.astype(str) + ', ' + df.R3.astype(str) + ', ' + df.R4.astype(str) + ', ' + df.R5.astype(str)+ ', ' + df.R6.astype(str)+ ', ' + df.R7.astype(str)+ ', ' + df.R8.astype(str)+ ', ' + df.R9.astype(str)+ ', ' + df.R10.astype(str)+ ', ' + df.R11.astype(str)+ ', ' + df.R12.astype(str)+ ', ' + df.R13.astype(str)+ ', ' + df.R14.astype(str)+ ', ' + df.R15.astype(str)+ ', ' + df.R16.astype(str))
#df= df.drop(['R1', 'R2', 'R3', 'R4', 'R5', 'R6', 'R7', 'R8', 'R9', 'R10', 'R11', 'R12', 'R13', 'R14', 'R15', 'R16'], axis=1)
#df = df.drop(['ID', 'Roll', 'Serial', 'DV'], axis = 1)
df.head()
df2 = df #Making a copy of the df in case I mess up
#df = df2

#Counting the number of flags' and 'no flags' and making the dataset less biased towards one side
flag_counter = 0
noflag_counter = 0

for word in df.FLAG:
  if word == "FLAG":
      flag_counter = flag_counter + 1
  else:
      noflag_counter = noflag_counter + 1


while noflag_counter >= flag_counter:
    RandomRoll = randrange(df.index[-1])
    if df.FLAG[RandomRoll] == 'NO FLAG':
      df = df.drop([RandomRoll])
      df.reset_index(drop=True, inplace=True)
      noflag_counter = noflag_counter - 1

#Creating test and train datasets
y = df.FLAG
x = df['ColumnR']
x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=0.2, random_state=7)
tfidf_vectorizer=TfidfVectorizer(stop_words='english', max_df=0.7)

#Creating classification model
tfidf_train=tfidf_vectorizer.fit_transform(x_train) 
tfidf_test=tfidf_vectorizer.transform(x_test)
pac=PassiveAggressiveClassifier()
pac.fit(tfidf_train,y_train)
y_pred=pac.predict(tfidf_test)
score=accuracy_score(y_test,y_pred)
print(f'Accuracy: {round(score*100,2)}%')

#Confusion matrix
confusion_matrix(y_test,y_pred, labels=['NO FLAG','FLAG'])
# Out:
#      <input type="file" id="files-00c064f9-ad81-4396-87f9-6e4f8e0736f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-00c064f9-ad81-4396-87f9-6e4f8e0736f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Import dataset
from google.colab import files
uploaded = files.upload()
import io

#Clean dataset
df = pd.read_csv(io.BytesIO(uploaded['CS Field Cleaning 9.28.22.csv']))
df.head()
df = df.assign(ColumnR = df.R1.astype(str) + ', ' + df.R2.astype(str) + ', ' + df.R3.astype(str) + ', ' + df.R4.astype(str) + ', ' + df.R5.astype(str)+ ', ' + df.R6.astype(str)+ ', ' + df.R7.astype(str)+ ', ' + df.R8.astype(str)+ ', ' + df.R9.astype(str)+ ', ' + df.R10.astype(str)+ ', ' + df.R11.astype(str)+ ', ' + df.R12.astype(str)+ ', ' + df.R13.astype(str)+ ', ' + df.R14.astype(str)+ ', ' + df.R15.astype(str)+ ', ' + df.R16.astype(str))
#df= df.drop(['R1', 'R2', 'R3', 'R4', 'R5', 'R6', 'R7', 'R8', 'R9', 'R10', 'R11', 'R12', 'R13', 'R14', 'R15', 'R16'], axis=1)
#df = df.drop(['ID', 'Roll', 'Serial', 'DV'], axis = 1)
df.head()
df2 = df #Making a copy of the df in case I mess up
#df = df2

#Applying model to dataset
import joblib
y2= df.FLAG
x2 = df['ColumnR']
tfidf_test=tfidf_vectorizer.transform(x2)
#Creating classification model
joblib.dump(pac, "model.pkl")
pac2 = joblib.load("model.pkl")
y2_pred = pac2.predict(tfidf_test)

#accuracy of prediction
#score=accuracy_score(y2,y2_pred)
#print(f'Accuracy: {round(score*100,2)}%')

#Confusion matrix
#confusion_matrix(y2,y2_pred, labels=['NO FLAG','FLAG'])
# Out:
#      <input type="file" id="files-379d372b-5040-46eb-8c56-6fd634a21b51" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-379d372b-5040-46eb-8c56-6fd634a21b51">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Exporting predicted dataset
df['FLAGPREDICTED'] = y2_pred
cu = "CU"
paypal = "PayPal"
creditunion = "Credit Union" 

for ind in df.index:
  if cu.lower() in df.ColumnR[ind].lower() or paypal.lower() in df.ColumnR[ind].lower() or creditunion.lower() in df.ColumnR[ind].lower():
    df.FLAGPREDICTED[ind] = "NO FLAG"

df.to_csv('Predicted CS Field Cleaning 9.28.22.csv', index=False)
files.download('Predicted CS Field Cleaning 9.28.22.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
